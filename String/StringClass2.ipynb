# %%
#dictionary
sales_record = {'price': 3.12,
                'sum_items': 4,
                'person':'swati'}
sales_statement = '{} brought {} items on a {} price of a total {}'
print(sales_statement.format(sales_record['person'],
                             sales_record['sum_items'],
                             sales_record['price'],
                             sales_record['sum_items']*sales_record['price']))
# Out:
# swati brought 4 items on a 3.12 price of a total 12.48
