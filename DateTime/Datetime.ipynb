# %%
import datetime
t = datetime.time(5,25,1)
print (t)
# Out:
# 05:25:01

# %%
t.hour
# Out:
# 5

# %%
t.minute
# Out:
# 25

# %%
print(datetime.time.max)
# Out:
# 23:59:59.999999

# %%
print(datetime.time.resolution)
# Out:
# 0:00:00.000001

# %%
#dates
today = datetime.date.today()
print(today)
# Out:
# 2020-06-04

# %%
today.timetuple()
# Out:
# time.struct_time(tm_year=2020, tm_mon=6, tm_mday=4, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=156, tm_isdst=-1)

# %%
today.month
# Out:
# 6

# %%
d1 = datetime.date(2015,3,11)
print(d1)
# Out:
# 2015-03-11

# %%
d2 = d1.replace(year=1990)

# %%
d2
# Out:
# datetime.date(1990, 3, 11)

# %%
d1-d2
# Out:
# datetime.timedelta(9131)
