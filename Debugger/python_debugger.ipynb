# %%
import pdb

# %%
x = [1,3,4]
y = 2
z = 3

result = y+z
print(result)

pdb.set_trace()

reult2 = y+x
print(result2)
# Out:
# 5
# --Return--
# > <ipython-input-3-eab7a14c6601>(8)<module>()->None
# -> pdb.set_trace()
# (Pdb) x
# [1, 3, 4]
# (Pdb) y
# 2
# (Pdb) z
# 3
# (Pdb) y+z
# 5
# (Pdb) x**2
# *** TypeError: unsupported operand type(s) for ** or pow(): 'list' and 'int'
# (Pdb) y**2
# 4
# (Pdb) q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-3-eab7a14c6601> in <module>()
#       6 print(result)
#       7
# ----> 8 pdb.set_trace()
#       9
#      10 reult2 = y+x
#
# /usr/lib/python3.6/bdb.py in trace_dispatch(self, frame, event, arg)
#      53             return self.dispatch_call(frame, arg)
#      54         if event == 'return':
# ---> 55             return self.dispatch_return(frame, arg)
#      56         if event == 'exception':
#      57             return self.dispatch_exception(frame, arg)
#
# /usr/lib/python3.6/bdb.py in dispatch_return(self, frame, arg)
# ...
