# %%
import csv

# %precision 2
with open('C:\Users\HP\Google Drive\Colab Notebooks','r') as mpgfile:
  mpg = list(csv.DietReader(csvfile))
mpg[:3]
# Out:
#   File "<ipython-input-3-62f5c82506d6>", line 4
#     with open('C:\Users\HP\Google Drive\Colab Notebooks','r') as mpgfile:
#              ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
